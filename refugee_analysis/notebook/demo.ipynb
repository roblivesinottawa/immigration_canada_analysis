# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from IPython.display import display

sns.set_style("darkgrid")

# %%
df = pd.read_csv("../data/demographics.csv", low_memory=False)

# %%
df.head()
# Out:
#    Year Country / territory of asylum/residence Location Name Female 0-4  \
# 0  2001                             Afghanistan         Kabul          0
# 1  2001                             Afghanistan       Various      14335
# 2  2001                             Afghanistan         Herat          0
# 3  2001                                  Angola         Viana        484
# 4  2001                                  Angola        Moxico        219
#
#   Female 5-11  Female 5-17 Female 12-17 Female 18-59 Female 60+  F: Unknown  \
# 0         NaN          1.0          NaN            1          0         0.0
# 1         NaN      45451.0          NaN        99880      19234    412004.0
# 2         NaN          0.0          NaN            1          0         0.0
# 3         NaN       1687.0          NaN         1282         43         0.0
# 4         NaN        734.0          NaN          427         25         0.0
#
# ...

# %%
df.tail()
# Out:
#        Year Country / territory of asylum/residence  \
# 18351  2016                                  Zambia
# 18352  2016                                  Zambia
# 18353  2016                                  Zambia
# 18354  2016                                Zimbabwe
# 18355  2016                                Zimbabwe
#
#                                        Location Name Female 0-4 Female 5-11  \
# 18351                           Mayukwayukwa : Point        983        1456
# 18352                                 Meheba : Point       1248        2364
# 18353  Zambia : Dispersed in the country / territory        637        1444
# 18354                                  Harare : City        220         117
# 18355                          Manicaland : Province        496         769
#
#        Female 5-17 Female 12-17 Female 18-59 Female 60+  F: Unknown F: Total  \
# 18351          NaN          934         2878        157         NaN     6408
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18356 entries, 0 to 18355
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Year                                     18356 non-null  int64
#  1   Country / territory of asylum/residence  18356 non-null  object
#  2   Location Name                            18355 non-null  object
#  3   Female 0-4                               17083 non-null  object
#  4   Female 5-11                              13927 non-null  object
#  5   Female 5-17                              3196 non-null   float64
#  6   Female 12-17                             13949 non-null  object
#  7   Female 18-59                             17694 non-null  object
#  8   Female 60+                               16900 non-null  object
#  9   F: Unknown                               12493 non-null  float64
# ...

# %%
df.describe()
# Out:
#                Year    Female 5-17    F: Unknown      Male 5-17    M: Unknown
# count  18356.000000    3196.000000  1.249300e+04    3196.000000  1.250000e+04
# mean    2010.314339    1449.903317  2.658836e+03    1536.136108  2.742023e+03
# std        4.386318   11492.117177  5.783491e+04   12276.757111  6.055912e+04
# min     2001.000000       0.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     2007.000000       1.000000  0.000000e+00       1.000000  0.000000e+00
# 50%     2011.000000      38.000000  0.000000e+00      44.000000  0.000000e+00
# 75%     2014.000000     696.000000  0.000000e+00     724.000000  0.000000e+00
# max     2016.000000  401884.000000  2.933164e+06  434058.000000  3.065738e+06

# %%
df.isna().sum()
# Out:
# Year                                           0
# Country / territory of asylum/residence        0
# Location Name                                  1
# Female 0-4                                  1273
# Female 5-11                                 4429
# Female 5-17                                15160
# Female 12-17                                4407
# Female 18-59                                 662
# Female 60+                                  1456
# F: Unknown                                  5863
# F: Total                                       0
# Male 0-4                                    1281
# Male 5-11                                   4406
# Male 5-17                                  15160
# Male 12-17                                  4370
# Male 18-59                                   436
# Male 60+                                    1370
# M: Unknown                                  5856
# M: Total                                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Country / territory of asylum/residence', 'Location Name',
#        'Female 0-4', 'Female 5-11', 'Female 5-17', 'Female 12-17',
#        'Female 18-59', 'Female 60+', 'F: Unknown', 'F: Total', 'Male 0-4',
#        'Male 5-11', 'Male 5-17', 'Male 12-17', 'Male 18-59', 'Male 60+',
#        'M: Unknown', 'M: Total'],
#       dtype='object')

# %%
df.rename(columns={"Country / territory of asylum/residence": "Country"}, inplace=True)

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Location Name', 'Female 0-4', 'Female 5-11',
#        'Female 5-17', 'Female 12-17', 'Female 18-59', 'Female 60+',
#        'F: Unknown', 'F: Total', 'Male 0-4', 'Male 5-11', 'Male 5-17',
#        'Male 12-17', 'Male 18-59', 'Male 60+', 'M: Unknown', 'M: Total'],
#       dtype='object')

# %%
len(df)
# Out:
# 18356

# %%
df[df['Country'] == "Brazil"]
# Out:
#        Year Country                                  Location Name Female 0-4  \
# 2596   2005  Brazil                                      Tocantins          0
# 2597   2005  Brazil                                      São Paulo          0
# 2598   2005  Brazil                                 Santa Catarina          0
# 2599   2005  Brazil                              Rio Grande do Sul          0
# 2600   2005  Brazil                            Rio Grande do Norte          0
# ...     ...     ...                                            ...        ...
# 12426  2014  Brazil                      Amazonas : Estado - State          4
# 12427  2014  Brazil                         Amapá : Estado - State          0
# 13689  2015  Brazil  Brazil : Dispersed in the country / territory        NaN
# 15652  2015  Brazil  Brazil : Dispersed in the country / territory          0
# 17032  2016  Brazil  Brazil : Dispersed in the country / territory          9
#
# ...

# %%
df[df["Country"] == "United States of America"]
# Out:
#        Year                   Country  \
# 15447  2014  United States of America
# 16872  2015  United States of America
#
#                                            Location Name Female 0-4  \
# 15447  United States of America : Dispersed in the co...          0
# 16872  United States of America : Dispersed in the co...          0
#
#       Female 5-11  Female 5-17 Female 12-17 Female 18-59 Female 60+  \
# 15447           0          NaN            0            0          0
# 16872           0          NaN            0            0          0
#
#        F: Unknown F: Total Male 0-4 Male 5-11  Male 5-17 Male 12-17  \
# 15447         0.0        0        0         0        NaN          0
# 16872         0.0        0        0         0        NaN          0
#
#       Male 18-59 Male 60+  M: Unknown M: Total
# 15447          0        0         0.0        0
# 16872          0        0         0.0        0

# %%
df[df["Country"] == "Afghanistan"]
# Out:
#        Year      Country                                      Location Name  \
# 0      2001  Afghanistan                                              Kabul
# 1      2001  Afghanistan                                            Various
# 2      2001  Afghanistan                                              Herat
# 546    2002  Afghanistan                                            Various
# 1162   2003  Afghanistan                                            Various
# ...     ...          ...                                                ...
# 16970  2016  Afghanistan                        Kapisa : Wilayat - Province
# 16971  2016  Afghanistan                         Khost : Wilayat - Province
# 16972  2016  Afghanistan                         Kabul : Wilayat - Province
# 16973  2016  Afghanistan                      Kandahar : Wilayat - Province
# 16974  2016  Afghanistan  Afghanistan : Dispersed in the country / terri...
#
# ...

# %%
df.query('Year == 2016')
# Out:
#        Year      Country                                  Location Name  \
# 16927  2016        Aruba   Aruba : Dispersed in the country / territory
# 16928  2016  Afghanistan                   Jawzjan : Wilayat - Province
# 16929  2016  Afghanistan                     Hirat : Wilayat - Province
# 16930  2016  Afghanistan                     Herat : Wilayat - Province
# 16931  2016  Afghanistan                   Helmand : Wilayat - Province
# ...     ...          ...                                            ...
# 18351  2016       Zambia                           Mayukwayukwa : Point
# 18352  2016       Zambia                                 Meheba : Point
# 18353  2016       Zambia  Zambia : Dispersed in the country / territory
# 18354  2016     Zimbabwe                                  Harare : City
# 18355  2016     Zimbabwe                          Manicaland : Province
#
#       Female 0-4 Female 5-11  Female 5-17 Female 12-17 Female 18-59  \
# ...

# %%
# replace all the nan values with the average
df.fillna(df.mean(), inplace=True)
# Out:
# /var/folders/83/_gttb8hn67dfsswspxfpc23w0000gn/T/ipykernel_50237/2233043033.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(), inplace=True)

# %%
df.head(10)
# Out:
#    Year      Country Location Name Female 0-4 Female 5-11  Female 5-17  \
# 0  2001  Afghanistan         Kabul          0         NaN          1.0
# 1  2001  Afghanistan       Various      14335         NaN      45451.0
# 2  2001  Afghanistan         Herat          0         NaN          0.0
# 3  2001       Angola         Viana        484         NaN       1687.0
# 4  2001       Angola        Moxico        219         NaN        734.0
# 5  2001       Angola       Malange         61         NaN        141.0
# 6  2001       Angola     Lunda Sul          7         NaN        109.0
# 7  2001       Angola   Lunda Norte         25         NaN         41.0
# 8  2001       Angola        Luanda         28         NaN         85.0
# 9  2001       Angola    Kwanza Sul          2         NaN         42.0
#
#   Female 12-17 Female 18-59 Female 60+  F: Unknown F: Total Male 0-4  \
# 0          NaN            1          0         0.0        2        0
# ...

# %%
cols = [
    "year",
    "country",
    "location",
    "female_0-4",
    "female_5-11",
    "female_5-17",
    "female_12-17",
    "female_18-59",
    "female_60+",
    "f:unknown",
    "f:total",
    "male_0-4",
    "male_5-11",
    "male_5-17",
    "male_12-17",
    "male_18-59",
    "male_60+",
    "m:unknown",
    "m:total"
]

df.columns = cols

# %%
df.head()
# Out:
#    year      country location female_0-4 female_5-11  female_5-17  \
# 0  2001  Afghanistan    Kabul          0         NaN          1.0
# 1  2001  Afghanistan  Various      14335         NaN      45451.0
# 2  2001  Afghanistan    Herat          0         NaN          0.0
# 3  2001       Angola    Viana        484         NaN       1687.0
# 4  2001       Angola   Moxico        219         NaN        734.0
#
#   female_12-17 female_18-59 female_60+  f:unknown f:total male_0-4 male_5-11  \
# 0          NaN            1          0        0.0       2        0       NaN
# 1          NaN        99880      19234   412004.0  590904    14716       NaN
# 2          NaN            1          0        0.0       1        0       NaN
# 3          NaN         1282         43        0.0    3496      597       NaN
# 4          NaN          427         25        0.0    1405      226       NaN
#
#    male_5-17 male_12-17 male_18-59 male_60+  m:unknown m:total
# ...

# %%
df.drop(["f:unknown", "m:unknown"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    year      country location female_0-4 female_5-11  female_5-17  \
# 0  2001  Afghanistan    Kabul          0         NaN          1.0
# 1  2001  Afghanistan  Various      14335         NaN      45451.0
# 2  2001  Afghanistan    Herat          0         NaN          0.0
# 3  2001       Angola    Viana        484         NaN       1687.0
# 4  2001       Angola   Moxico        219         NaN        734.0
#
#   female_12-17 female_18-59 female_60+ f:total male_0-4 male_5-11  male_5-17  \
# 0          NaN            1          0       2        0       NaN        0.0
# 1          NaN        99880      19234  590904    14716       NaN    47522.0
# 2          NaN            1          0       1        0       NaN        0.0
# 3          NaN         1282         43    3496      597       NaN     1645.0
# 4          NaN          427         25    1405      226       NaN      711.0
#
#   male_12-17 male_18-59 male_60+ m:total
# 0        NaN          2        0       2
# ...

# %%
df.drop(["f:total", "m:total"], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#    year      country     location female_0-4 female_5-11  female_5-17  \
# 0  2001  Afghanistan        Kabul          0         NaN          1.0
# 1  2001  Afghanistan      Various      14335         NaN      45451.0
# 2  2001  Afghanistan        Herat          0         NaN          0.0
# 3  2001       Angola        Viana        484         NaN       1687.0
# 4  2001       Angola       Moxico        219         NaN        734.0
# 5  2001       Angola      Malange         61         NaN        141.0
# 6  2001       Angola    Lunda Sul          7         NaN        109.0
# 7  2001       Angola  Lunda Norte         25         NaN         41.0
# 8  2001       Angola       Luanda         28         NaN         85.0
# 9  2001       Angola   Kwanza Sul          2         NaN         42.0
#
#   female_12-17 female_18-59 female_60+ male_0-4 male_5-11  male_5-17  \
# 0          NaN            1          0        0       NaN        0.0
# ...
